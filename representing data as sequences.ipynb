# %% [markdown]
# # Representing Data as Sequences

# %% [markdown]
# ### Limitation of itemsets
#
# - itemset representation ignores order and quanity
# - vector representation handles quantity... but what about order?

# %% [markdown]
# ### Example: Course Recommendater System
#
# - **Pattern**: Many people who have taken "data mining" have also taken "python programming".
# - **Recommender**: You have taken "data mining", so it is recommended you take "python programming"

# %% [markdown]
# ### Order matters in reality...
#
# ![image.png](attachment:image.png)
#
# - Viewed this model of laptop on dell.com as shown in this Facebook ad.
# - Ended up purhcasing a different model.
# - **Having already purchased another model, is this ad relevant anymore?**

# %% [markdown]
# ### From itemset to sequence
#
# - **Complex Data object**: a curriculum path, a DNA sequence, a session of search queries, a sentence (of words), a sequence of user actions
#
# ![image.png](attachment:image.png)
#
# **Categorical items** organized in a sequential order

# %% [markdown]
# ### The Sequence Representations
#
# ![image.png](attachment:image.png)
#
# - $x_k$ is the categorical item that appears at the $k_{th}$ position of $X$.

# %% [markdown]
# ### Example of Biological Sequences
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of Behavioral Sequences
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# - Items: queries, URL's, clickthroughs
