# %% [markdown]
# # Applying SVD to Text Data

# %% [markdown]
# ### A real example: text mining
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Applying SVD
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SVD transformation (original docs)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SVD transformation (new doc)
#
# ![image.png](attachment:image.png)
