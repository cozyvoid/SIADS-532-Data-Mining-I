# %% [markdown]
# # The Vector Space

# %% [markdown]
# ### Coordinate system and vector space
#
# ![image.png](attachment:image.png)
#
# - Every dimension -> coordinate
# - Vector: direction + magnitude
# - Vector space defines basic operations of vectors

# %% [markdown]
# ### Practice: text data
#
# - Document 1: "text mining"
# - Document 2: "data science data"
# - Document 3: "text data"
#
# How can we construct the vector space or coordinate system of this text data?

# %% [markdown]
# - Vocabulary: {"text", "mining", "data", "science"}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What you should know
#
# - How to represent numerical data as vectors and matrix
# - Difference between itemsets and vectors
# - Vector space facilitates many data mining operations on vector data
