# %% [markdown]
# # Transforming the Coordinate System

# %% [markdown]
# ### A real scenario: movie ratings
#
# - Simple case:
#     - two movies
#     - many users
#     - numerical ratings

# %% [markdown]
# ### Original vector space
#
# - Coordinates: two movies (we hope they are orthogonal, but...)
# - Data sort of correlated, but noisy
# - What if we map this data to a new coordinate system?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Find the first coordinate
#
# - This upward sloping line seems to capture the major correlation trend
#     - e.g., "epics"
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Find the second coordinate
#
# - Should be orthogonal to the first coordinate.
# - Captures the rest of the variance
#     - e.g., Brad Pitt movies
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The vector space becomes...
#
# - Lossless transformation
# - Much more compact and intuitive
# - New coordinates are called principal components
#
# ![image.png](attachment:image.png)
