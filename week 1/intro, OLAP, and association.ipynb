# %% [markdown]
# # Introduction: OLAP and Association

# %% [markdown]
# ### Four-Dimensions of Data Mining
#
# - Data to be mined
# - Knowledge to be Discovered
#     - also known as "data mining functionalities"
# - Techniques Utilized
# - Applications adopted

# %% [markdown]
# ## Data Mining Functionalities
#
# - Online Analytical Processing (OLAP)
# - Association
# - Classification
# - Prediction
# - Clustering
# - Ranking
# - Outlier/Anomaly detection

# %% [markdown]
# ### OLAP: Online Analytical Processing
#
# - Fast answering of multidimensional analytical queries
# - Analytical processing instead of transaction processing

# %% [markdown]
# ### Transactional vs. Analytical Processing
#
# - Typical transactional database table and records
# - Easy to query instances of transactions
#     - "How many TV's were sold in total?"
# - What about analytical queries that support business decisions?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Query: how many TV's were sold in the second quarter of 2011 in North America?

# %% [markdown]
# ### OLAP: Online Analytical Processing
#
# - Techniques:
#     - **Data Warehouses**: Infrastructure that integrates multiple types of transactional data and processes data for analysis
#     - **Data Cubing**: Pre-aggregate transactional data for use in future queries; improves efficiencies.

# %% [markdown]
# ### OLAP: Online Analytical Processing
#
# - Application
#     - Business Intelligence

# %% [markdown]
# ### Association
# - Finding inherent regularities and relations in big data
#
# ![image.png](attachment:image.png)
#
# - **Techniques**: Co-occurrence analysis, correlation analysis, and causal inference
# - **Applications**: Basket data analysis, catalog design, advertisement, and search engine log analysis
#
# ![image-2.png](attachment:image-2.png)
#
# "What are the best combination of keywords that are associated with my search engine ad?"
