# %% [markdown]
# ## Itemsets, Vectors/Matrices, and Sequences

# %% [markdown]
# ### Data Representations
#
# ![image.png](attachment:image.png) ->
#
# - Item set
# - Vector/Matrix
# - Sequence
# - Time Series
# - Spatial
# - Spatiotemporal
# - Graph/Network
# - Stream

# %% [markdown]
# ### Itemset Data
#
# - **Data object**: a shopping basket, a piece of text, a board of directors, ...
#
# ![image.png](attachment:image.png)
#
# - **Attribute**: *appearance* of a *categorical item*
#     - a product, a word, a person, etc.

# %% [markdown]
# ### The Itemset Represenation

# %% [markdown]
# Each data object is represented as a set of items:
#
# $
# X = {x_1, x_2, ... , x_k}
# $
#
# - $x_i$ belongs to $X$ if and only if that *categorical item* appears in the set
# - Order or counts of the items don't matter

# %% [markdown]
# ### Example of Itemsets
#
# Shopping Baskets:
#
# ![image.png](attachment:image.png)
#
# Text (as bag-of-words):
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Vector Data
#
# - **Data Object**: e.g., a user's rating of products, or course grades of a student
#
# ![image.png](attachment:image.png)
#
# - **Attribute**: a *numerical* property of the object.
#     - e.g., Kimono = 5; Shoe = 4; Piano = 3, etc.

# %% [markdown]
# ### The Vector Representation
#
# Data represented as n-dimensional vectors:
# - Each dimension corresponds to one attribute
#
# ![image.png](attachment:image.png)
#
# - $x_1$ is the *numerical value* of $X$ at the $i^th$ dimension (attribute)
# - Each attribute is unique; cannot change order.
# - Multiple objects -> a *matrix* (a collection of vectors)

# %% [markdown]
# ### Example of Matrices
#
# - Product Ratings
#
# ![image.png](attachment:image.png)
#
# - Microarrays
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Sequence Data
#
# - Data object: curriculum paths, a DNA sequence, a session of searcgh queries, a sentence (of words), a trace of user actions
# - Attributes: pairs of *positions* and *categorical item*, in a sequential *order*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Sequence Representation
#
# - Data represented as a *sequence of items*:
#
# $
# X = {(x_1, 1), (x_2, 2), ..., (x_k, k)}
# $
#
# - $x_i$ is the cateforical item appeared at the $i_th$ position of $X$.

# %% [markdown]
# ### Example of Sequences
#
# - DNA sequences
#
# ![image.png](attachment:image.png)
#
# - Search sequence
#
# ![image-2.png](attachment:image-2.png)
